# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/tensors/ImageManagement.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # Challenge: Image Management

# %% [markdown]
# ## Instructions
#
# This is a self-correcting notebook generated by [nbgrader](https://github.com/jupyter/nbgrader).
#
# Complete the cells beginning with `# YOUR CODE HERE` and run the subsequent cells to check your code.

# %% [markdown]
# ## Package setup

# %%
# Import needed packages
# You may add or remove packages should you need them
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import load_sample_images

# Display plots inline and change plot resolution to retina
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Loading samples images

# %%
# Load samples images
images = np.asarray(load_sample_images().images)
print('Number of images: ' + str(len(images)))
print('Shape of images tensor: ' + str(images.shape))

first_image = images[0]
# Display first image
plt.imshow(first_image)

# Print details about first image
print('Shape of each image: ' + str(first_image.shape))
print('RGB values of top left image pixel: ' + str(first_image[0][0]))

# %% [markdown]
# ## Question
#
# Store in a variable named `rgb_values` the RGB values of the bottom right pixel.

# %%
# YOUR CODE HERE

# %%
print(rgb_values)
assert rgb_values.shape == (3,)
assert np.array_equal([15,24,7], rgb_values)

# %% [markdown]
# ## Question
#
# Reshape the previous `images` tensor into a 2D tensor.

# %%
# YOUR CODE HERE

# %%
# Assert new tensor dimensions
# 819840 = 427x640x3 
assert images.shape == (2, 819840)
# Assert RGB values of first pixel in first image
assert np.array_equal([174, 201, 231], images[0,:3])
# Assert RGB values of last pixel in first image
assert np.array_equal([15,24,7], images[0,819837:])
