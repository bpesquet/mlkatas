# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/notebooks/katas/algorithms/CNN_CIFAR10.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# ## Instructions
#
# This is a self-correcting exercise generated by [nbgrader](https://github.com/jupyter/nbgrader).
#
# Fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Run subsequent cells to check your code.

# %% [markdown]
# ---

# %% [markdown]
# # Kata: Classify Common Images
#
# In this kata, you'll train models to associate images representing common objects with their class.
#
# The [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset consists of 60,000 32x32 colour images in 10 classes, with 6,000 images per class. The classes are completely mutually exclusive. There are 50,000 training images and 10,000 test images.
#
# ![CIFAR10 images](images/cifar10.png)

# %% [markdown]
# ## Package setup

# %%
# The mlkatas package contains various utility functions required by all katas
# !pip install mlkatas

# %%
# Import base packages
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import mlkatas

# %%
# Setup plots
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10, 10
# %config InlineBackend.figure_format = 'retina'
sns.set()

# %%
# Import ML packages (edit this list if needed)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

print(f'TensorFlow version: {tf.__version__}')
print(f'Keras version: {tf.keras.__version__}')

# %% [markdown]
# ## Step 1: Loading the data

# %% [markdown]
# ### Question
#
# * Load the CIFAR10 dataset included with Keras.
# * Display the first 30 test images.

# %%
# Load the data

# YOUR CODE HERE

# %%
# Plot the first 30 images

# YOUR CODE HERE

# %% [markdown]
# ## Step 2: Training a dense neural network

# %% [markdown]
# ### Question
#
# * Prepare data for training with a dense network. Set apart the first 10,000 images as validation data.
# * Train a model on the data to obtain a validation accuracy > 45%. Store the training history in a variable named `history`.

# %%
# Prepare data for training

# YOUR CODE HERE

# %%
# Create and train a model

# YOUR CODE HERE

# %%
# Plot training history
mlkatas.plot_loss_acc(history)

# %%
# Retrieve final validation accuracy
val_acc = history.history['val_acc'][-1]

# Assert final accuracy
assert val_acc > 0.45

# %%
# Evaluate model performance on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f'Test accuracy: {test_acc * 100:.2f}%')

# %% [markdown]
# ## Step 3: Training a convnet

# %% [markdown]
# ### Question
#
# * Prepare data for training with a convolutional network. Set apart the first 10,000 images as validation data.
# * Train a model on the data to obtain a validation accuracy around 70%. Store the training history in a variable named `history`.

# %%
# Prepare data for training

# YOUR CODE HERE

# %%
# Create a convnet

# YOUR CODE HERE

# %%
# Train the convnet

# YOUR CODE HERE

# %%
# Plot training history
mlkatas.plot_loss_acc(history)

# %%
# Retrieve final validation accuracy
val_acc = history.history['val_acc'][-1]

# Assert final validation accuracy
assert val_acc > 0.68

# %%
# Evaluate model performance on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f'Test accuracy: {test_acc * 100:.2f}%')
