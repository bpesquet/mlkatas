# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/algorithms/DNN_Iris.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# ## Instructions
#
# This is a self-correcting exercise generated by [nbgrader](https://github.com/jupyter/nbgrader).
#
# Fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Run subsequent cells to check your code.

# %% [markdown]
# ---

# %% [markdown]
# # Kata: Iris Dataset
#
# [Iris](https://archive.ics.uci.edu/ml/datasets/iris) is a well-known multiclass dataset. It contains 3 classes of flowers with 50 examples each. There are a total of 4 features for each flower. The goal here is to identify a flower's class.
#
# ![](images/Iris-versicolor-21_1.jpg)

# %% [markdown]
# ## Package setup

# %%
# The mlkatas package contains various utility functions required by all katas
# !pip install mlkatas

# %%
# Import base packages
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import mlkatas

# %%
# Setup plots
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10, 10
# %config InlineBackend.figure_format = 'retina'
sns.set()

# %%
# Import ML packages (edit this list if needed)
from sklearn.datasets import load_iris
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import to_categorical

print(f'TensorFlow version: {tf.__version__}')
print(f'Keras version: {tf.keras.__version__}')

# %% [markdown]
# ## Step 1: Loading the data

# %%
# Load the Iris dataset included with scikit-learn
dataset = load_iris()

# Put data in a pandas DataFrame
df_iris = pd.DataFrame(dataset.data, columns=dataset.feature_names)
# Add target and class to DataFrame
df_iris['target'] = dataset.target
df_iris['class'] = dataset.target_names[dataset.target]
# Show 10 random samples
df_iris.sample(n=10)

# %% [markdown]
# ### Question
#
# Store training input data in a variable named `x_train` and training targets in a variable named `y_train`.

# %%
# YOUR CODE HERE

# %%
print(f'x_train: {x_train.shape}. y_train: {y_train.shape}')
print(f'Labels: {y_train}')

assert x_train.shape == (150,4)
assert y_train.shape == (150,)

# %% [markdown]
# ## Step 2: Preparing the data

# %% [markdown]
# ### Question
#
# Reshape `y_train` to one-hot encode the targets in a (150,3) matrix.

# %%
# YOUR CODE HERE

# %%
# Show a sample of encoded targets
df_iris_labels = pd.DataFrame(y_train)
df_iris_labels.sample(n=10)

# %%
print(f'y_train: {y_train.shape}')

assert y_train.shape == (150,3)
assert np.array_equal([1,0,0], y_train[0])
assert np.array_equal([0,1,0], y_train[50])
assert np.array_equal([0,0,1], y_train[100])

# %% [markdown]
# ## Step 3: Training a model

# %% [markdown]
# ### Question
#
# Train a model on the data to obtain a training accuracy > 93%. Store the training history in a variable named `history`.
#
# Tip: for best results, use the Adam optimizer with a learning rate of 0.1.
#
# ```python
# model.compile(Adam(lr=0.1), loss='categorical_crossentropy', metrics=['accuracy'])
# ```

# %%
# Train a multiclass classifier on the data

# YOUR CODE HERE

# %%
# Plot training history
mlkatas.plot_loss_acc(history)

# %%
# Retrieve final accuracy
final_acc = history.history['acc'][-1]

# Assert final accuracy
assert final_acc > 0.93
