# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/notebooks/katas/algorithms/KNN_Scratch.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# ## Instructions
#
# This is a self-correcting exercise generated by [nbgrader](https://github.com/jupyter/nbgrader).
#
# Fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Run subsequent cells to check your code.

# %% [markdown]
# ---

# %% [markdown]
# # Kata: Code K-Nearest Neighbors From Scratch

# %% [markdown]
# ## Objectives

# %% [markdown]
# - Use scikit-learn's `KNeighborsClassifier` on a dataset of your choice (for example, the well-known Iris dataset).
# - Code a k-nearest neighbors classifier from scratch.
# - Compare your classifier's and scikit-learn's performance on the same dataset.
